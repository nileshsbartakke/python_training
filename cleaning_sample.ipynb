# %% [markdown]
# # Loading data

# %%
import pandas as pd


dataset=pd.read_csv("all-people-2019-09-25.csv")
# Out:
# C:\New folder\new python\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (28,29,37,52,53,54,57,58,59,60,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Visual Inspect

# %%
dataset.head()
# Out:
#    Date Added                 Name First Name  Last Name             Stage  \
# 0  2019-09-18  Elizabeth Olivencia  Elizabeth  Olivencia      Hot Prospect
# 1  2019-09-18   Shavonne Lancaster   Shavonne  Lancaster  Engaged Prospect
# 2  2019-09-18        Kelly Allesch      Kelly    Allesch           Nurture
# 3  2019-09-18              Frances    Frances        NaN           Nurture
# 4  2019-09-18          Jesus Beato      Jesus      Beato      Hot Prospect
#
#    Lead Source      Assigned To Is Contacted  Listing Price  \
# 0     Referral       Alex Lopez           No            NaN
# 1       Zillow    Allyson Carey          Yes       189900.0
# 2  Realtor.com     Austin Brown          Yes        42000.0
# 3  Realtor.com      Debbie Pape           No        59999.0
# 4  Realtor.com  Michael Vasquez           No        84900.0
#
#                                  Tags  ...     ID Agent who set Appt.?  \
# 0          1st Time Home Buyer, Buyer  ...  14650                  NaN
# ...

# %%
dataset.tail()
# Out:
#        Date Added           Name     First Name Last Name    Stage  \
# 12518  2017-08-14  Michele Waite        Michele     Waite  Nurture
# 12519  2017-08-14      Nathan Or         Nathan        Or  Nurture
# 12520  2017-08-13   Cathy Deschu          Cathy    Deschu  Nurture
# 12521  2017-08-14     Test Email           Test     Email  Nurture
# 12522  2017-08-14  Grullonbianca  Grullonbianca       NaN  Nurture
#
#                  Lead Source      Assigned To Is Contacted  Listing Price  \
# 12518             Kunversion  Daniel Berenato           No            NaN
# 12519             Kunversion      Debbie Pape           No        89900.0
# 12520            Realtor.com      Debbie Pape           No        79900.0
# 12521  Alex - Realtor.com/SG  Daniel Berenato          Yes            NaN
# 12522       Alex - Zillow/SG  Daniel Berenato          Yes            NaN
#
#                                                     Tags  ...   ID  \
# ...

# %%
dataset.columns
# Out:
# Index(['Date Added', 'Name', 'First Name', 'Last Name', 'Stage', 'Lead Source',
#        'Assigned To', 'Is Contacted', 'Listing Price', 'Tags',
#        ...
#        'ID', 'Agent who set Appt.?', 'Appointment Ran?', 'Date Appt. Set?',
#        'Date Appt.Set For?', 'Showing Specialist', 'SV: Analyzed Date',
#        'SV: Buckets', 'SV: Reason for Disqualification',
#        'SV: Relevant for Outreach'],
#       dtype='object', length=101)

# %%
dataset.shape
# Out:
# (12523, 101)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12523 entries, 0 to 12522
# Columns: 101 entries, Date Added to SV: Relevant for Outreach
# dtypes: float64(34), int64(1), object(66)
# memory usage: 9.6+ MB

# %%
dataset.count()
# Out:
# Date Added                         12523
# Name                               12523
# First Name                         12505
# Last Name                          10199
# Stage                              12523
# Lead Source                        12523
# Assigned To                        12523
# Is Contacted                       12523
# Listing Price                       8286
# Tags                               12191
# Email 1                            11719
# Email 1 - Type                     11679
# Email 2                              463
# Email 2 - Type                       459
# Email 3                               16
# Email 3 - Type                        16
# Email 4                                0
# Email 4 - Type                         0
# Email 5                                0
# Email 5 - Type                         0
# Email 6                                0
# Email 6 - Type                         0
# Phone 1                             9494
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
#rename columns in pandas dataset.rename(columns={'old':'new'},inplace=True)
dataset.rename(columns={'Property State':'Property_State'}, inplace=True)
dataset.rename(columns={'Listing Price':'Listing_Price'}, inplace=True)

# %%
#Value Count in columns 
#dataset.Property_State.value_counts(dropna=True)
dataset.Listing_Price.value_counts(dropna=False).head()
# Out:
# NaN         4237
# 345000.0     257
# 145000.0     211
# 159900.0     168
# 315000.0     167
# Name: Listing_Price, dtype: int64
