# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('bigmart_data.csv')
df.describe
df.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data_bm=df.dropna(how='any')
data_bm.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
data_sorted1=data_bm[data_bm['Outlet_Establishment_Year']==1999]
data_sorted.head(5)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15          9.3          Low Fat         0.016047
# 2            FDN15         17.5          Low Fat         0.016760
# 10           FDY07         11.8          Low Fat         0.000000
# 12           FDX32         15.1          Regular         0.100014
# 17           FDP49          9.0          Regular         0.069196
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0                   Dairy  249.8092            OUT049
# 2                    Meat  141.6180            OUT049
# 10  Fruits and Vegetables   45.5402            OUT049
# 12  Fruits and Vegetables  145.4786            OUT049
# 17              Breakfast   54.3614            OUT049
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                        1999      Medium               Tier 1
# 2                        1999      Medium               Tier 1
# ...

# %%
#data_sorted1=data_bm.sort_values(by='Outlet_Establishment_Year',ascending=False,inplace=True)
#data_sorted.head(5)
# Out:
# C:\New folder\new python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_sorted2=data_bm.sort_values(by=['Outlet_Establishment_Year','Item_Outlet_Sales'],ascending=False)[:5]
data_sorted2
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 43             FDC02        21.35          Low Fat         0.069103
# 2803           FDU51        20.20          Regular         0.096907
# 641            FDY51        12.50          Low Fat         0.081465
# 2282           NCX30        16.70          Low Fat         0.026729
# 2887           FDR25        17.00          Regular         0.140090
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 43       Canned  259.9278            OUT018                       2009
# 2803       Meat  175.5028            OUT018                       2009
# 641        Meat  220.7798            OUT018                       2009
# 2282  Household  248.4776            OUT018                       2009
# 2887     Canned  265.1884            OUT018                       2009
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data_sorted2=data_bm.sort_values(by=['Outlet_Establishment_Year','Item_Outlet_Sales'],ascending=False)[:5]
data_sorted2
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 43             FDC02        21.35          Low Fat         0.069103
# 2803           FDU51        20.20          Regular         0.096907
# 641            FDY51        12.50          Low Fat         0.081465
# 2282           NCX30        16.70          Low Fat         0.026729
# 2887           FDR25        17.00          Regular         0.140090
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 43       Canned  259.9278            OUT018                       2009
# 2803       Meat  175.5028            OUT018                       2009
# 641        Meat  220.7798            OUT018                       2009
# 2282  Household  248.4776            OUT018                       2009
# 2887     Canned  265.1884            OUT018                       2009
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
#Sorted_index
data1=data_bm.sort_index()
data1.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
df1=pd.DataFrame({'A':['A0','A1','A2','A3'],'B':['B0','B1','B2','B3'],
                  'C':['C0','C1','C3','C3'],'D':['D0','D1','D2','D3']},index=[0,1,2,3])
df2=pd.DataFrame({'A':['A4','A5','A6','A7'],'B':['B4','B5','B6','B7'],
                  'C':['C4','C5','C6','C7'],'D':['D4','D4','D5','D7']},index=[4,5,6,7])
df3=pd.DataFrame({'A':['A8','A9','A10','A11'],'B':['B8','B9','B10','B11'],
                  'C':['C8','C9','C10','C11'],'D':['D8','D9','D10','D11']},index=[8,9,10,11])

# %%
result=pd.concat([df1,df2,df3])
result.head(15)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C3   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D4
# 6    A6   B6   C6   D5
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result=pd.concat([df1,df2,df3],keys=['x','y','z'])
result.head(15)
# Out:
#         A    B    C    D
# x 0    A0   B0   C0   D0
#   1    A1   B1   C1   D1
#   2    A2   B2   C3   D2
#   3    A3   B3   C3   D3
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D4
#   6    A6   B6   C6   D5
#   7    A7   B7   C7   D7
# z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %%
#TO Get Second Dataframe
result.loc['z']
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4=pd.DataFrame({'B':['B2','B3','B6','B7'],'D':['D2','D3','D6','D7'],'F':['F2','F3','F6','F7']},index=[2,3,6,7])
df4
result1=pd.concat([df1,df4],axis=1,sort=False)
print(result1)
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C3   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result2=pd.concat([df1,df4],axis=1,join='inner')  
result2
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C3  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3
